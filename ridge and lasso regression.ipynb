# %%
from sklearn.datasets import fetch_california_housing
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df=fetch_california_housing()

# %%
dataset=pd.DataFrame(df.data)

# %%
dataset.head()
# Out:
#         0     1         2         3       4         5      6       7
# 0  8.3252  41.0  6.984127  1.023810   322.0  2.555556  37.88 -122.23
# 1  8.3014  21.0  6.238137  0.971880  2401.0  2.109842  37.86 -122.22
# 2  7.2574  52.0  8.288136  1.073446   496.0  2.802260  37.85 -122.24
# 3  5.6431  52.0  5.817352  1.073059   558.0  2.547945  37.85 -122.25
# 4  3.8462  52.0  6.281853  1.081081   565.0  2.181467  37.85 -122.25

# %%
#independent and dependent features
X=dataset
y=df.target
y
# Out:
# array([4.526, 3.585, 3.521, ..., 0.923, 0.847, 0.894])

# %%
#train test split
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.30, random_state=42
)

# %%
#standardization
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
X_train=scaler.fit_transform(X_train)
X_test=scaler.transform(X_test)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import cross_val_score
regressor=LinearRegression()
regressor.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
me=cross_val_score(regressor,X_train,y_train,scoring='neg_mean_squared_error',cv=5)

# %%
np.mean(me)
# Out:
# np.float64(-0.5268253746355748)

# %%
ye=regressor.predict(X_test)
print("ksjds",ye)
# Out:
# ksjds [0.72604907 1.76743383 2.71092161 ... 2.07465531 1.57371395 1.82744133]

# %%
import seaborn as sns
sns.distplot(ye-y_test)
# Out:
# C:\Users\Dell 5490T\AppData\Local\Temp\ipykernel_17472\297308780.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(ye-y_test)
# <Axes: ylabel='Density'>

# %% [markdown]
# Ridge regression Algorithm

# %%
from sklearn.linear_model import Ridge
from sklearn.model_selection import GridSearchCV
ridge=Ridge()
parameters={'alpha':[1,2,5,10,20,30,35,40,45,50,55,60,70,80,90]}
ridge_regressor=GridSearchCV(ridge,parameters,scoring='neg_mean_squared_error',cv=5)
ridge_regressor.fit(X_train,y_train)
# Out:
# GridSearchCV(cv=5, estimator=Ridge(),
#              param_grid={'alpha': [1, 2, 5, 10, 20, 30, 35, 40, 45, 50, 55, 60,
#                                    70, 80, 90]},
#              scoring='neg_mean_squared_error')

# %%
print(ridge_regressor.best_params_)
# Out:
# {'alpha': 5}

# %%
print(ridge_regressor.best_score_)
# Out:
# -0.5268179966861514

# %%
ridge_preder=ridge_regressor.predict(X_test)
ridge_preder
# Out:
# array([0.72799408, 1.76647219, 2.70889662, ..., 2.07364426, 1.57452579,
#        1.82666041])

# %%
import seaborn as sns
sns.distplot(ridge_preder-y_test)
# Out:
# C:\Users\Dell 5490T\AppData\Local\Temp\ipykernel_17472\200447571.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(ridge_preder-y_test)
# <Axes: ylabel='Density'>

# %%
from sklearn.metrics import r2_score

score=r2_score(ridge_preder,y_test)
score
# Out:
# 0.34383945441404373
